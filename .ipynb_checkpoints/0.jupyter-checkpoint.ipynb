# %% [markdown]
# # 시작하기 전에
#
# ## 0. 환경 설정
# ## 1. python 환경 구성
# ### 1.1 아나콘다 설치
#
# ### 1.2 advanced install
# https://www.python.org/downloads/
#
# ### 1.3 google colab
# https://colab.research.google.com/
#
#
#
# ## 2. IPython
# from IPython.display import Image
# Image(url= "http://ipython.org/_static/IPy_header.png")
#
# * A powerful interactive shell.
# * A kernel for Jupyter.
# * Support for interactive data visualization and use of GUI toolkits.
# * Flexible, embeddable interpreters to load into your own projects.
# * Easy to use, high performance tools for parallel computing.
#
# Read Eval Print Loop -> Lisp code
# Loop print eval read
#
# ## 3. Notebook
#
#          webSocket          0MQ
# Notebook <----> API Server <----> Python Kernel
#
# IPython Notebook
# Jupyter Notebook
# Jupyper Lab
# jupyter lab
#
# # pip
# * python package 를 관리해주는 도구
# ## pip list
# - 현재 내 환경에 설치된 패키지 리스트 -
#
# ## pip install numpy
# ## pip uninstall numpy
#
#
# ## 1. Jupiter notebook
# ## 1.1. Live Code Example
# shift + enter
#
# ctl+shift+ -
# ## 1.2 mark down
#   http://jupyter-notebook.readthedocs.io/en/stable/index.html
#
# ## 1.2.1 Lisp
#
# ## 1.2.2 수식
# $$x = {-b \pm \sqrt{b^2-4ac} \over 2a}$$
#
#
# ## 1.2.2 images
#
# from IPython.display import Image
# Image(url= "https://www.cosy.sbg.ac.at/~pmeerw/Watermarking/lena_color.gif")
#
# ## 1.2.3. loading video ##
#
# @[youtube](http://www.youtube.com/embed/dQw4w9WgXcQ)
#
# from IPython.display import YouTubeVideo
# YouTubeVideo("dQw4w9WgXcQ")
#
# ## 1.2.4 tables ##
#
# ## 1.2.5 chart ##
#
# ## 1.2.6. 성능 측정 ##
# - line 측정
#
# %timeit 3+4
#
# ## 셀단위 측정
# %time
#
# name = ['손오공', '저팔계', '사오정']
#
# for i in name:
#     print(i)
#
# ## The Evolution of the Jupyter Notebook ##
#
# ## 1. Basic Python ##
# https://learnxinyminutes.com/docs/python/
#
#
#
#
#
#
# https://wikidocs.net/
